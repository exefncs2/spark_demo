# %%
from pyspark.sql import SparkSession

# 創建 SparkSession
spark = SparkSession.builder \
    .appName("Jupyter PySpark Example") \
    .master("local[*]") \
    .getOrCreate()

# 創建 DataFrame
data = [("Alice", 34), ("Bob", 45), ("Catherine", 29)]
columns = ["Name", "Age"]

df = spark.createDataFrame(data, columns)

# 顯示 DataFrame 內容
df.show()

# 停止 SparkSession
spark.stop()
# Out:
# WARNING: log4j.properties is not found. HADOOP_CONF_DIR may be incomplete.
# your 131072x1 screen size is bogus. expect trouble
# WARNING: Using incubator modules: jdk.incubator.vector
# {"ts":"2024-07-24T15:20:13.123Z","level":"INFO","msg":"Running Spark version 4.0.0-preview1","logger":"SparkContext"}
# {"ts":"2024-07-24T15:20:13.139Z","level":"INFO","msg":"OS info Linux, 5.15.153.1-microsoft-standard-WSL2, amd64","logger":"SparkContext"}
# {"ts":"2024-07-24T15:20:13.141Z","level":"INFO","msg":"Java version 17.0.6","logger":"SparkContext"}
# {"ts":"2024-07-24T15:20:13.504Z","level":"WARN","msg":"Unable to load native-hadoop library for your platform... using builtin-java classes where applicable","logger":"NativeCodeLoader"}
# {"ts":"2024-07-24T15:20:14.101Z","level":"INFO","msg":"==============================================================","logger":"ResourceUtils"}
# {"ts":"2024-07-24T15:20:14.102Z","level":"INFO","msg":"No custom resources configured for spark.driver.","logger":"ResourceUtils"}
# {"ts":"2024-07-24T15:20:14.102Z","level":"INFO","msg":"==============================================================","logger":"ResourceUtils"}
# {"ts":"2024-07-24T15:20:14.109Z","level":"INFO","msg":"Submitted application: Jupyter PySpark Example","logger":"SparkContext"}
# {"ts":"2024-07-24T15:20:14.207Z","level":"INFO","msg":"Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)","logger":"ResourceProfile"}
# {"ts":"2024-07-24T15:20:14.210Z","level":"INFO","msg":"Limiting resource is cpu","logger":"ResourceProfile"}
# {"ts":"2024-07-24T15:20:14.211Z","level":"INFO","msg":"Added ResourceProfile id: 0","logger":"ResourceProfileManager"}
# {"ts":"2024-07-24T15:20:14.474Z","level":"INFO","msg":"Changing view acls to: felix","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:14.475Z","level":"INFO","msg":"Changing modify acls to: felix","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:14.475Z","level":"INFO","msg":"Changing view acls groups to: ","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:14.476Z","level":"INFO","msg":"Changing modify acls groups to: ","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:14.483Z","level":"INFO","msg":"SecurityManager: authentication disabled; ui acls disabled; users with view permissions: felix; groups with view permissions: EMPTY; users with modify permissions: felix; groups with modify permissions: EMPTY; RPC SSL disabled","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:14.960Z","level":"INFO","msg":"Successfully started service 'sparkDriver' on port 34645.","logger":"Utils"}
# {"ts":"2024-07-24T15:20:15.071Z","level":"INFO","msg":"Registering MapOutputTracker","logger":"SparkEnv"}
# {"ts":"2024-07-24T15:20:15.083Z","level":"INFO","msg":"Registering BlockManagerMaster","logger":"SparkEnv"}
# {"ts":"2024-07-24T15:20:15.105Z","level":"INFO","msg":"Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information","logger":"BlockManagerMasterEndpoint"}
# {"ts":"2024-07-24T15:20:15.106Z","level":"INFO","msg":"BlockManagerMasterEndpoint up","logger":"BlockManagerMasterEndpoint"}
# {"ts":"2024-07-24T15:20:15.126Z","level":"INFO","msg":"Registering BlockManagerMasterHeartbeat","logger":"SparkEnv"}
# {"ts":"2024-07-24T15:20:15.181Z","level":"INFO","msg":"Created local directory at /tmp/blockmgr-65ec1644-99a2-4137-8e61-a3b9a63a1933","logger":"DiskBlockManager"}
# {"ts":"2024-07-24T15:20:15.222Z","level":"INFO","msg":"Registering OutputCommitCoordinator","logger":"SparkEnv"}
# {"ts":"2024-07-24T15:20:15.681Z","level":"INFO","msg":"Start Jetty 127.0.0.1:4040 for SparkUI","logger":"JettyUtils"}
# {"ts":"2024-07-24T15:20:15.755Z","level":"INFO","msg":"Successfully started service 'SparkUI' on port 4040.","logger":"Utils"}
# {"ts":"2024-07-24T15:20:15.936Z","level":"INFO","msg":"Changing view acls to: felix","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:15.936Z","level":"INFO","msg":"Changing modify acls to: felix","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:15.937Z","level":"INFO","msg":"Changing view acls groups to: ","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:15.937Z","level":"INFO","msg":"Changing modify acls groups to: ","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:15.937Z","level":"INFO","msg":"SecurityManager: authentication disabled; ui acls disabled; users with view permissions: felix; groups with view permissions: EMPTY; users with modify permissions: felix; groups with modify permissions: EMPTY; RPC SSL disabled","logger":"SecurityManager"}
# {"ts":"2024-07-24T15:20:16.127Z","level":"INFO","msg":"Starting executor ID driver on host localhost","logger":"Executor"}
# {"ts":"2024-07-24T15:20:16.135Z","level":"INFO","msg":"OS info Linux, 5.15.153.1-microsoft-standard-WSL2, amd64","logger":"Executor"}
# {"ts":"2024-07-24T15:20:16.136Z","level":"INFO","msg":"Java version 17.0.6","logger":"Executor"}
# {"ts":"2024-07-24T15:20:16.270Z","level":"INFO","msg":"Starting executor with user classpath (userClassPathFirst = false): ''","logger":"Executor"}
# {"ts":"2024-07-24T15:20:16.271Z","level":"INFO","msg":"Created or updated repl class loader org.apache.spark.util.MutableURLClassLoader@27251c8 for default.","logger":"Executor"}
# {"ts":"2024-07-24T15:20:16.410Z","level":"INFO","msg":"Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 38543.","logger":"Utils"}
# {"ts":"2024-07-24T15:20:16.425Z","level":"INFO","msg":"Server created on localhost:38543","logger":"NettyBlockTransferService"}
# {"ts":"2024-07-24T15:20:16.442Z","level":"INFO","msg":"Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy","logger":"BlockManager"}
# {"ts":"2024-07-24T15:20:16.464Z","level":"INFO","msg":"Registering BlockManager BlockManagerId(driver, localhost, 38543, None)","logger":"BlockManagerMaster"}
# {"ts":"2024-07-24T15:20:16.482Z","level":"INFO","msg":"Registering block manager localhost:38543 with 434.4 MiB RAM, BlockManagerId(driver, localhost, 38543, None)","logger":"BlockManagerMasterEndpoint"}
# {"ts":"2024-07-24T15:20:16.486Z","level":"INFO","msg":"Registered BlockManager BlockManagerId(driver, localhost, 38543, None)","logger":"BlockManagerMaster"}
# {"ts":"2024-07-24T15:20:16.488Z","level":"INFO","msg":"Initialized BlockManager: BlockManagerId(driver, localhost, 38543, None)","logger":"BlockManager"}
# {"ts":"2024-07-24T15:20:17.493Z","level":"INFO","msg":"Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.","logger":"SharedState"}
# {"ts":"2024-07-24T15:20:17.504Z","level":"INFO","msg":"Warehouse path is 'file:/home/felix/spark_demo/notebooks/spark-warehouse'.","logger":"SharedState"}
# {"ts":"2024-07-24T15:20:23.597Z","level":"INFO","msg":"Code generated in 283.508696 ms","logger":"CodeGenerator"}
# {"ts":"2024-07-24T15:20:23.727Z","level":"INFO","msg":"Starting job: showString at NativeMethodAccessorImpl.java:0","logger":"SparkContext"}
# {"ts":"2024-07-24T15:20:23.768Z","level":"INFO","msg":"Got job 0 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:23.769Z","level":"INFO","msg":"Final stage: ResultStage 0 (showString at NativeMethodAccessorImpl.java:0)","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:23.770Z","level":"INFO","msg":"Parents of final stage: List()","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:23.773Z","level":"INFO","msg":"Missing parents: List()","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:23.779Z","level":"INFO","msg":"Submitting ResultStage 0 (MapPartitionsRDD[6] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:23.927Z","level":"INFO","msg":"MemoryStore started with capacity 434.4 MiB","logger":"MemoryStore"}
# {"ts":"2024-07-24T15:20:24.044Z","level":"INFO","msg":"Block broadcast_0 stored as values in memory (estimated size 13.3 KiB, free 434.4 MiB)","logger":"MemoryStore"}
# {"ts":"2024-07-24T15:20:24.163Z","level":"INFO","msg":"Block broadcast_0_piece0 stored as bytes in memory (estimated size 6.9 KiB, free 434.4 MiB)","logger":"MemoryStore"}
# {"ts":"2024-07-24T15:20:24.167Z","level":"INFO","msg":"Added broadcast_0_piece0 in memory on localhost:38543 (size: 6.9 KiB, free: 434.4 MiB)","logger":"BlockManagerInfo"}
# {"ts":"2024-07-24T15:20:24.171Z","level":"INFO","msg":"Created broadcast 0 from broadcast at DAGScheduler.scala:1641","logger":"SparkContext"}
# {"ts":"2024-07-24T15:20:24.199Z","level":"INFO","msg":"Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[6] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:24.203Z","level":"INFO","msg":"Adding task set 0.0 with 1 tasks resource profile 0","logger":"TaskSchedulerImpl"}
# {"ts":"2024-07-24T15:20:24.235Z","level":"INFO","msg":"Starting task 0.0 in stage 0.0 (TID 0) (localhost,executor driver, partition 0, PROCESS_LOCAL, 7739 bytes) ","logger":"TaskSetManager"}
# {"ts":"2024-07-24T15:20:24.270Z","level":"INFO","msg":"Running task 0.0 in stage 0.0 (TID 0)","context":{"task_name":"task 0.0 in stage 0.0 (TID 0)"},"logger":"Executor"}
# {"ts":"2024-07-24T15:20:25.403Z","level":"INFO","msg":"Code generated in 19.084813 ms","context":{"task_name":"task 0.0 in stage 0.0 (TID 0)"},"logger":"CodeGenerator"}
# {"ts":"2024-07-24T15:20:25.556Z","level":"INFO","msg":"Times: total = 1153, boot = 949, init = 204, finish = 0","context":{"task_name":"task 0.0 in stage 0.0 (TID 0)"},"logger":"PythonRunner"}
# {"ts":"2024-07-24T15:20:25.625Z","level":"INFO","msg":"Finished task 0.0 in stage 0.0 (TID 0). 2005 bytes result sent to driver","context":{"task_name":"task 0.0 in stage 0.0 (TID 0)"},"logger":"Executor"}
# {"ts":"2024-07-24T15:20:25.642Z","level":"INFO","msg":"Finished task 0.0 in stage 0.0 (TID 0) in 1420 ms on localhost (executor driver) (1/1)","logger":"TaskSetManager"}
# {"ts":"2024-07-24T15:20:25.646Z","level":"INFO","msg":"Removed TaskSet 0.0, whose tasks have all completed, from pool ","logger":"TaskSchedulerImpl"}
# {"ts":"2024-07-24T15:20:25.788Z","level":"INFO","msg":"Connected to AccumulatorServer at host: 127.0.0.1 port: 50043","logger":"PythonAccumulatorV2"}
# {"ts":"2024-07-24T15:20:25.792Z","level":"INFO","msg":"ResultStage 0 (showString at NativeMethodAccessorImpl.java:0) finished in 1960 ms","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:25.799Z","level":"INFO","msg":"Job 0 is finished. Cancelling potential speculative or zombie tasks for this job","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:25.799Z","level":"INFO","msg":"Canceling stage 0","logger":"TaskSchedulerImpl"}
# {"ts":"2024-07-24T15:20:25.800Z","level":"INFO","msg":"Killing all running tasks in stage 0: Stage finished","logger":"TaskSchedulerImpl"}
# {"ts":"2024-07-24T15:20:25.803Z","level":"INFO","msg":"Job 0 finished: showString at NativeMethodAccessorImpl.java:0, took 2.074712 s","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:25.813Z","level":"INFO","msg":"Starting job: showString at NativeMethodAccessorImpl.java:0","logger":"SparkContext"}
# {"ts":"2024-07-24T15:20:25.815Z","level":"INFO","msg":"Got job 1 (showString at NativeMethodAccessorImpl.java:0) with 3 output partitions","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:25.815Z","level":"INFO","msg":"Final stage: ResultStage 1 (showString at NativeMethodAccessorImpl.java:0)","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:25.816Z","level":"INFO","msg":"Parents of final stage: List()","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:25.816Z","level":"INFO","msg":"Missing parents: List()","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:25.817Z","level":"INFO","msg":"Submitting ResultStage 1 (MapPartitionsRDD[6] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:25.831Z","level":"INFO","msg":"Block broadcast_1 stored as values in memory (estimated size 13.3 KiB, free 434.4 MiB)","logger":"MemoryStore"}
# {"ts":"2024-07-24T15:20:25.839Z","level":"INFO","msg":"Block broadcast_1_piece0 stored as bytes in memory (estimated size 6.9 KiB, free 434.4 MiB)","logger":"MemoryStore"}
# {"ts":"2024-07-24T15:20:25.841Z","level":"INFO","msg":"Added broadcast_1_piece0 in memory on localhost:38543 (size: 6.9 KiB, free: 434.4 MiB)","logger":"BlockManagerInfo"}
# {"ts":"2024-07-24T15:20:25.842Z","level":"INFO","msg":"Created broadcast 1 from broadcast at DAGScheduler.scala:1641","logger":"SparkContext"}
# {"ts":"2024-07-24T15:20:25.843Z","level":"INFO","msg":"Submitting 3 missing tasks from ResultStage 1 (MapPartitionsRDD[6] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(1, 2, 3))","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:25.848Z","level":"INFO","msg":"Adding task set 1.0 with 3 tasks resource profile 0","logger":"TaskSchedulerImpl"}
# {"ts":"2024-07-24T15:20:25.850Z","level":"INFO","msg":"Starting task 0.0 in stage 1.0 (TID 1) (localhost,executor driver, partition 1, PROCESS_LOCAL, 7776 bytes) ","logger":"TaskSetManager"}
# {"ts":"2024-07-24T15:20:25.850Z","level":"INFO","msg":"Starting task 1.0 in stage 1.0 (TID 2) (localhost,executor driver, partition 2, PROCESS_LOCAL, 7774 bytes) ","logger":"TaskSetManager"}
# {"ts":"2024-07-24T15:20:25.851Z","level":"INFO","msg":"Starting task 2.0 in stage 1.0 (TID 3) (localhost,executor driver, partition 3, PROCESS_LOCAL, 7780 bytes) ","logger":"TaskSetManager"}
# {"ts":"2024-07-24T15:20:25.852Z","level":"INFO","msg":"Running task 0.0 in stage 1.0 (TID 1)","context":{"task_name":"task 0.0 in stage 1.0 (TID 1)"},"logger":"Executor"}
# {"ts":"2024-07-24T15:20:25.863Z","level":"INFO","msg":"Removed broadcast_0_piece0 on localhost:38543 in memory (size: 6.9 KiB, free: 434.4 MiB)","logger":"BlockManagerInfo"}
# {"ts":"2024-07-24T15:20:25.865Z","level":"INFO","msg":"Running task 1.0 in stage 1.0 (TID 2)","context":{"task_name":"task 1.0 in stage 1.0 (TID 2)"},"logger":"Executor"}
# {"ts":"2024-07-24T15:20:25.871Z","level":"INFO","msg":"Running task 2.0 in stage 1.0 (TID 3)","context":{"task_name":"task 2.0 in stage 1.0 (TID 3)"},"logger":"Executor"}
# {"ts":"2024-07-24T15:20:26.016Z","level":"INFO","msg":"Times: total = 138, boot = -300, init = 437, finish = 1","context":{"task_name":"task 0.0 in stage 1.0 (TID 1)"},"logger":"PythonRunner"}
# {"ts":"2024-07-24T15:20:26.031Z","level":"INFO","msg":"Finished task 0.0 in stage 1.0 (TID 1). 2047 bytes result sent to driver","context":{"task_name":"task 0.0 in stage 1.0 (TID 1)"},"logger":"Executor"}
# {"ts":"2024-07-24T15:20:26.035Z","level":"INFO","msg":"Finished task 0.0 in stage 1.0 (TID 1) in 186 ms on localhost (executor driver) (1/3)","logger":"TaskSetManager"}
# {"ts":"2024-07-24T15:20:26.052Z","level":"INFO","msg":"Times: total = 171, boot = 8, init = 163, finish = 0","context":{"task_name":"task 2.0 in stage 1.0 (TID 3)"},"logger":"PythonRunner"}
# {"ts":"2024-07-24T15:20:26.059Z","level":"INFO","msg":"Finished task 2.0 in stage 1.0 (TID 3). 2008 bytes result sent to driver","context":{"task_name":"task 2.0 in stage 1.0 (TID 3)"},"logger":"Executor"}
# {"ts":"2024-07-24T15:20:26.059Z","level":"INFO","msg":"Times: total = 185, boot = 12, init = 173, finish = 0","context":{"task_name":"task 1.0 in stage 1.0 (TID 2)"},"logger":"PythonRunner"}
# {"ts":"2024-07-24T15:20:26.065Z","level":"INFO","msg":"Finished task 1.0 in stage 1.0 (TID 2). 2002 bytes result sent to driver","context":{"task_name":"task 1.0 in stage 1.0 (TID 2)"},"logger":"Executor"}
# {"ts":"2024-07-24T15:20:26.070Z","level":"INFO","msg":"Finished task 2.0 in stage 1.0 (TID 3) in 219 ms on localhost (executor driver) (2/3)","logger":"TaskSetManager"}
# {"ts":"2024-07-24T15:20:26.071Z","level":"INFO","msg":"Finished task 1.0 in stage 1.0 (TID 2) in 221 ms on localhost (executor driver) (3/3)","logger":"TaskSetManager"}
# {"ts":"2024-07-24T15:20:26.071Z","level":"INFO","msg":"Removed TaskSet 1.0, whose tasks have all completed, from pool ","logger":"TaskSchedulerImpl"}
# {"ts":"2024-07-24T15:20:26.072Z","level":"INFO","msg":"ResultStage 1 (showString at NativeMethodAccessorImpl.java:0) finished in 251 ms","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:26.072Z","level":"INFO","msg":"Job 1 is finished. Cancelling potential speculative or zombie tasks for this job","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:26.073Z","level":"INFO","msg":"Canceling stage 1","logger":"TaskSchedulerImpl"}
# {"ts":"2024-07-24T15:20:26.073Z","level":"INFO","msg":"Killing all running tasks in stage 1: Stage finished","logger":"TaskSchedulerImpl"}
# {"ts":"2024-07-24T15:20:26.073Z","level":"INFO","msg":"Job 1 finished: showString at NativeMethodAccessorImpl.java:0, took 0.259410 s","logger":"DAGScheduler"}
# {"ts":"2024-07-24T15:20:26.546Z","level":"INFO","msg":"Removed broadcast_1_piece0 on localhost:38543 in memory (size: 6.9 KiB, free: 434.4 MiB)","logger":"BlockManagerInfo"}
# {"ts":"2024-07-24T15:20:27.524Z","level":"INFO","msg":"Code generated in 18.865204 ms","logger":"CodeGenerator"}
# {"ts":"2024-07-24T15:20:27.545Z","level":"INFO","msg":"SparkContext is stopping with exitCode 0 from stop at NativeMethodAccessorImpl.java:0.","logger":"SparkContext"}
# {"ts":"2024-07-24T15:20:27.558Z","level":"INFO","msg":"Stopped Spark web UI at http://localhost:4040","logger":"SparkUI"}
# {"ts":"2024-07-24T15:20:27.571Z","level":"INFO","msg":"MapOutputTrackerMasterEndpoint stopped!","logger":"MapOutputTrackerMasterEndpoint"}
# {"ts":"2024-07-24T15:20:27.611Z","level":"INFO","msg":"MemoryStore cleared","logger":"MemoryStore"}
# {"ts":"2024-07-24T15:20:27.611Z","level":"INFO","msg":"BlockManager stopped","logger":"BlockManager"}
# {"ts":"2024-07-24T15:20:27.616Z","level":"INFO","msg":"BlockManagerMaster stopped","logger":"BlockManagerMaster"}
# {"ts":"2024-07-24T15:20:27.618Z","level":"INFO","msg":"OutputCommitCoordinator stopped!","logger":"OutputCommitCoordinator$OutputCommitCoordinatorEndpoint"}
# {"ts":"2024-07-24T15:20:27.637Z","level":"INFO","msg":"Successfully stopped SparkContext","logger":"SparkContext"}
# +---------+---+
# |     Name|Age|
# +---------+---+
# |    Alice| 34|
# |      Bob| 45|
# |Catherine| 29|
# +---------+---+
